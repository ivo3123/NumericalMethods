# %% [markdown]
# The table presents data about the development of a bacterial population:
#
# |Time (hours)|Cells count (x1000)|
# |:-:|:-:|
# |1|1|
# |2|12|
# |3|110|
# |4|1037|
# |5|12218|
#
# Find an adequate function to interpolatate the data.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append('../util')

from basis_poly import exp_poly

# %%
nodes = np.array([1, 2, 3, 4, 5])
values = np.array([1, 12, 110, 1037, 12218])

# %%
x_axis = np.linspace(nodes.min(), nodes.max(), 400)

plt.scatter(nodes, values)
plt.plot(x_axis, exp_poly(nodes, values, x_axis))
plt.title('Exponential polynomial')
plt.legend(['data', 'exponential poly'])
plt.show()
