# %% [markdown]
# |Blood alcohol level|Relative risk of crashing|
# |:-:|:-:|
# |0|1|
# |0.03|1.06|
# |0.07|2.09|
# |0.15|22.1|
# |0.21|99.78|
# |0.27|328.602|
#
# Construct an interpolation polynomial whcih describes the data from the table.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append('../util')

from basis_poly import exp_poly

# %%
nodes = np.array([0, 0.03, 0.07, 0.15, 0.21, 0.27])
values = np.array([1, 1.06, 2.09, 22.1, 99.78, 328.602])

# %%
x_axis = np.linspace(nodes.min(), nodes.max(), 400)

plt.scatter(nodes, values)
plt.plot(x_axis, exp_poly(nodes, values, x_axis))
plt.title('Exponential polynomial')
plt.legend(['data', 'exponential poly'])
plt.show()
