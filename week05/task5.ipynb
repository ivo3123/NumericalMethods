# %% [markdown]
# |Time|Accelaration|
# |:-:|:-:|
# |1|0|
# |1.5|1|
# |3|1.2|
# |4|4|
# |6|2|
#
# Construct a trigonometric polynomial with period of:
# * $2 \pi $
# * 8

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append('../util')

from basis_poly import trig_poly, transform_nodes_from_period

# %%
nodes = np.array([1, 1.5, 3, 4, 6])
values = np.array([0, 1, 1.2, 4, 2])

x_axis = np.linspace(np.min(nodes) - 4, np.max(values) + 5, 600)

plt.scatter(nodes, values)
plt.plot(x_axis, trig_poly(nodes, values, x_axis))
plt.title('Trigonometric poly with period $2 \\pi$')
plt.legend(['data', 'trig poly'])
plt.show()

# %%
nodes = np.array([1, 1.5, 3, 4, 6])
values = np.array([0, 1, 1.2, 4, 2])

period = 8

x_axis = np.linspace(np.min(nodes) - 4, np.max(values) + 5, 600)

nodes = transform_nodes_from_period(nodes, period)

plt.scatter(nodes, values)
plt.plot(x_axis, trig_poly(nodes, values, x_axis))
plt.title('Trigonometric poly with period 8')
plt.legend(['data', 'trig poly'])
plt.show()
