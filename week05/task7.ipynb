# %% [markdown]
# |Time|pH|
# |:-:|:-:|
# |2|7|
# |5|7.1|
# |7|7.4|
# |11|8.2|
# |14|8.9|
# |18|8.4|
# |21|7.3|
# |24|7|
#
# Construct a trigonometric polynomial with a period of 24.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append('../util')

from basis_poly import trig_poly, transform_nodes_from_period

# %%
nodes = np.array([2, 5, 7, 11, 14, 16, 18, 21, 24])
values = np.array([7, 7.1, 7.4, 8.2, 8.9, 8.4, 7.9, 7.3, 7])

nodes = transform_nodes_from_period(nodes, period := 24)

# %%
x_axis = np.linspace(np.min(nodes) - 7, np.max(nodes) + 7, 400)

plt.scatter(nodes, values)
plt.plot(x_axis, trig_poly(nodes, values, x_axis))
plt.legend(['points', 'trig poly'])
plt.show()
